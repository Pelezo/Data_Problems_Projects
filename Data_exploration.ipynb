# %%
##libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix,roc_curve, auc
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc

# %% [markdown]
# ## **Data Loading/Data exploration**

# %% [markdown]
# ### **Takeways from the EDA**
#
# - The data shows information  about different individuals.
#
# - Most of the data types are floats and ints and it contains 159256 rows and 24 columns. The data set  contains categorical and numerical values. The categorical values are already  properly  encoded.
#
# - The statistical Information  about the dataset shows the min and the max of each column also the standard deviation  and the mean. This dataset is used to predict smoking status, the mean of 44 in the age provide insights into the age group that is most represented in the data. Similarly for the rest of the numerical columns.
#
# - The record of the duplicates in the dataset are not real duplicates. They represent different individual with similar information.
#
# - The data contains  no missing value.
#
# ### **Data Visualization**
#
# - **Age:** The distribution of age appears to be roughly normally distributed with a peak around middle age. This suggests that the dataset includes a good representation of individuals across different age groups.
#
# - **Height:** The histogram for height shows a relatively normal distribution with a slight skew towards taller individuals. This is expected as height typically follows a normal distribution in the population.
#
# - **Weight:** The distribution of weight shows a wider spread with a longer tail towards higher weights. This indicates the presence of individuals with a range of body weights, including some who may be considered overweight or obese.
#
# - These takeaways provide valuable insights into the distribution of various health indicators within the dataset and can guide further analysis and modeling efforts.
#
# - The distribution  of the of each variable based on the target shows the most promsing features for the machine learning. The most promising features are  hemoglobin, waist, weight, HDL.
#
# - There are no any visible outliers in the data.

# %%
#Loading  the data
df=pd.read_csv('train.csv')
df.head(5)
# Out:
#    id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0   55         165          60       81.0             0.5
# 1   1   70         165          65       89.0             0.6
# 2   2   20         170          75       81.0             0.4
# 3   3   35         180          95      105.0             1.5
# 4   4   30         165          60       80.5             1.5
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  HDL  LDL  \
# 0              0.6              1               1       135  ...   40   75
# 1              0.7              2               2       146  ...   57  126
# 2              0.5              1               1       118  ...   45   93
# 3              1.2              1               1       131  ...   38  102
# 4              1.0              1               1       121  ...   44   93
#
#    hemoglobin  Urine protein  serum creatinine  AST  ALT  Gtp  dental caries  \
# ...

# %%
#infomation about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159256 entries, 0 to 159255
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   159256 non-null  int64
#  1   age                  159256 non-null  int64
#  2   height(cm)           159256 non-null  int64
#  3   weight(kg)           159256 non-null  int64
#  4   waist(cm)            159256 non-null  float64
#  5   eyesight(left)       159256 non-null  float64
#  6   eyesight(right)      159256 non-null  float64
#  7   hearing(left)        159256 non-null  int64
#  8   hearing(right)       159256 non-null  int64
#  9   systolic             159256 non-null  int64
#  10  relaxation           159256 non-null  int64
#  11  fasting blood sugar  159256 non-null  int64
#  12  Cholesterol          159256 non-null  int64
#  13  triglyceride         159256 non-null  int64
#  14  HDL                  159256 non-null  int64
# ...

# %%
# THe number of columns and rows
df.shape
# Out:
# (159256, 24)

# %%
#Statistical information  about the data
df.describe()
# Out:
#                   id            age     height(cm)     weight(kg)  \
# count  159256.000000  159256.000000  159256.000000  159256.000000
# mean    79627.500000      44.306626     165.266929      67.143662
# std     45973.391572      11.842286       8.818970      12.586198
# min         0.000000      20.000000     135.000000      30.000000
# 25%     39813.750000      40.000000     160.000000      60.000000
# 50%     79627.500000      40.000000     165.000000      65.000000
# 75%    119441.250000      55.000000     170.000000      75.000000
# max    159255.000000      85.000000     190.000000     130.000000
#
#            waist(cm)  eyesight(left)  eyesight(right)  hearing(left)  \
# count  159256.000000   159256.000000    159256.000000  159256.000000
# mean       83.001990        1.005798         1.000989       1.023974
# std         8.957937        0.402113         0.392299       0.152969
# min        51.000000        0.100000         0.100000       1.000000
# ...

# %%
#Checking for the missing values
missing_values=df.isnull().sum()
missing_values
# Out:
# id                     0
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# dental caries          0
# smoking                0
# dtype: int64

# %%
##Checking for any duplicates
df['duplicate'] = df.duplicated()
df.head(20)
# Out:
#     id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0    0   55         165          60       81.0             0.5
# 1    1   70         165          65       89.0             0.6
# 2    2   20         170          75       81.0             0.4
# 3    3   35         180          95      105.0             1.5
# 4    4   30         165          60       80.5             1.5
# 5    5   50         170          55       51.0             1.2
# 6    6   45         160          55       69.0             1.5
# 7    7   55         155          60       84.5             0.7
# 8    8   40         165          70       89.0             0.7
# 9    9   40         155          50       73.0             1.5
# 10  10   40         155          50       68.0             0.8
# 11  11   50         160          45       64.0             1.2
# 12  12   40         155          55       80.0             0.8
# 13  13   40         170          65       81.0             1.2
# ...

# %%
##Checking for any duplicates
df['duplicate'] = df.duplicated()
df.tail(20)
# Out:
#             id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 159236  159236   60         165          55       79.0             0.9
# 159237  159237   45         170          80       92.5             1.0
# 159238  159238   35         165          65       76.0             0.3
# 159239  159239   25         170          70       87.0             1.0
# 159240  159240   40         160          45       66.0             1.2
# 159241  159241   40         175          70       82.1             1.2
# 159242  159242   60         170          70       83.0             0.6
# 159243  159243   60         170          65       81.6             0.7
# 159244  159244   40         170          85       99.0             0.9
# 159245  159245   35         175          80       87.2             0.7
# 159246  159246   40         165          60       70.0             0.9
# 159247  159247   20         170          55       71.0             1.2
# ...

# %%
# Check if the target variable is binary
unique_target_values = df['smoking'].unique()
if len(unique_target_values) == 2:
  # Binary classification
  print("This is a binary classification problem.")
else:
  # Regression
  print("This is a regression problem.")
# Out:
# This is a binary classification problem.

# %%
##The target variable column
target_column = 'smoking'
df[target_column].head(10)
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# 5    1
# 6    0
# 7    0
# 8    1
# 9    0
# Name: smoking, dtype: int64

# %%
df.drop('duplicate', axis=1, inplace=True)

# %%
df.drop('id', axis=1, inplace=True)

# %%
df.head(5)
# Out:
#    age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0   55         165          60       81.0             0.5              0.6
# 1   70         165          65       89.0             0.6              0.7
# 2   20         170          75       81.0             0.4              0.5
# 3   35         180          95      105.0             1.5              1.2
# 4   30         165          60       80.5             1.5              1.0
#
#    hearing(left)  hearing(right)  systolic  relaxation  ...  HDL  LDL  \
# 0              1               1       135          87  ...   40   75
# 1              2               2       146          83  ...   57  126
# 2              1               1       118          75  ...   45   93
# 3              1               1       131          88  ...   38  102
# 4              1               1       121          76  ...   44   93
#
#    hemoglobin  Urine protein  serum creatinine  AST  ALT  Gtp  dental caries  \
# ...
